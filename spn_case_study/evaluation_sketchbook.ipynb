# %%
from spn_tools.run_simulation import plot_results, load_log
import os
import matplotlib.pyplot as plt

# %%
# os.chdir("/home/nifrec/documents/master_1/bio_modelling/model_ass/snakes_spn")
# run_to_log = load_log(os.path.join("test_runs", "2022-05-19_11-16-49", "exp_0"))

save_dir = "/home/nifrec/documents/master_1/bio_modelling/"\
    + "model_ass/snakes_spn/test_runs/2022-05-19_12-04-40/exp_0/logs.json"
run_to_log = load_log(save_dir)
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(10, 20))
plot_results(run_to_log=run_to_log, x_var="time", 
             y_vars = ["pdn", "gbpdn"], num_timeboxes=1000,
             ax=axes[0])
plot_results(run_to_log=run_to_log, x_var="time", 
             y_vars = ["gr_pdn", "gr_gbpdn", "gr_free"], num_timeboxes=1000,
             ax=axes[1])
# Out:
# /home/nifrec/Vault/Documents/master_1/bio_modelling/model_ass/snakes_spn/spn_tools/run_simulation.py:311: UserWarning: TODO: cleanup!
#   warnings.warn("TODO: cleanup!")
# /home/nifrec/Vault/Documents/master_1/bio_modelling/model_ass/snakes_spn/spn_tools/run_simulation.py:311: UserWarning: TODO: cleanup!
#   warnings.warn("TODO: cleanup!")
# <AxesSubplot:xlabel='time'>
